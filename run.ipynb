# %%
# %run statistics2.py
# Out:
# 元データ
# [4 1 3 2 6 8 6 3 1 2]
#
# ソート済みデータ
# [1 1 2 2 3 3 4 6 6 8]
#
# 要素数N は
# N=10
#
# スタージェスの公式より、要素数10のとき、階級数m は
# m=5.32
# よって、小数点以下を切り上げて
# m=6
#
# 階級幅は小数点以下第2位まで求める。
# 最大値8、最小値1、階級数6 より階級幅c は
# c=1.17
#
# 階級幅1.17より、度数分布表は次の通り
# 0             階級 度数 相対度数 累積度数 累積相対度数
# 1   1.0以上、2.17未満  4  0.4    4    0.4
# 2  2.17以上、3.34未満  2  0.2    6    0.6
# 3  3.34以上、4.51未満  1  0.1    7    0.7
# 4  4.51以上、5.68未満  0  0.0    7    0.7
# 5  5.68以上、6.85未満  2  0.2    9    0.9
# 6  6.85以上、8.02未満  1  0.1   10    1.0
# 7  8.02以上、9.19未満  0  0.0   10    1.0
#
# 最頻値は
# [1, 2, 3, 6]
#
# 中央値は
# 3
# 3
# 3.0
#
# 第一四分位数は2、第三四分位数は6
#
# 平均値は
# 3.6
#
# 分散は
# 5.04
#
# 標準偏差は
# 2.24
#
# 標本平均の分散を求めている場合は、元の分散をnで割る
# 標本分散の期待値v^2 は、元の分散σ^2 の(n-1) / n 倍
# 不偏分散の期待値s^2は、標本分散の期待値v^2の n / (n-1)倍
